# %% [markdown]
# # Fourier Transform

# %%
# %matplotlib inline
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('img/bridge.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
img = cv2.imread('img/bridge.jpg', 0)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))
plt.subplot(121)
plt.imshow(img, cmap = 'gray')
plt.title('Original')
plt.xticks([])
plt.yticks([])
plt.subplot(122)
plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# ### 1. Given a 256x256 image

# %% [markdown]
# * (a) Perform the Fourier transform, keeping only 1/4 largest coefficients, and perform inverse transform to obtain image A.

# %%
img = cv2.imread('img/bridge.jpg', 0)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
rows, cols = img.shape
crow, ccol = rows // 4 , cols // 4
fshift[:3*crow, :3*ccol] = 0
f_ishift = np.fft.ifftshift(fshift)
img_a = np.fft.ifft2(f_ishift)
img_a = np.abs(img_a)
plt.subplot(121)
plt.imshow(img, cmap = 'gray')
plt.title('Original')
plt.xticks([])
plt.yticks([])
plt.subplot(122)
plt.imshow(img_a, cmap = 'gray')
plt.title('A')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# * (b) Divide the image into 256 16x16 blocks. Perform Fourier Transform on each block, keeping only 1/4 largest coefficients in each block, and take inverse transform to obtain image B.

# %%
img = cv2.imread('img/bridge.jpg', 0)
img_list = [[] for i in range(256)]
img_b = list()
for i in range(256):
    for j in img[i:i+1]:
        for k in img[i:i+1]:
            img_list[i].append(k)
for i in img_list:
    f = np.fft.fft2(i)
    fshift = np.fft.fftshift(f)
    rows, cols = img.shape
    crow, ccol = rows // 4 , cols // 4
    fshift[:3*crow, :3*ccol] = 0
    f_ishift = np.fft.ifftshift(fshift)
    j = np.fft.ifft2(f_ishift)
    j = np.abs(j)
    k = [j[0]]
    img_b += k
plt.subplot(121)
plt.imshow(img, cmap = 'gray')
plt.title('Original')
plt.xticks([])
plt.yticks([])
plt.subplot(122)
plt.imshow(img_b, cmap = 'gray')
plt.title('B')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# * (c) Reduce the size of the original image to 128x128 by sub-sampling or averaging. Perform Fourier Transform on the 128x128 image. Zero-pad the coefficient matrix to a 256x256 array. Then perform inverse transform to obtain image C.

# %%
img = cv2.imread('img/bridge.jpg', 0)
img_128 = cv2.resize(img, dsize=(128, 128))
f = np.fft.fft2(img_128, [256, 256])
fshift = np.fft.fftshift(f)
rows, cols = img.shape
crow, ccol = rows // 256 , cols // 256
f_ishift = np.fft.ifftshift(fshift)
img_c = np.fft.ifft2(f_ishift)
img_c = np.abs(img_c)
plt.subplot(121)
plt.imshow(img, cmap = 'gray')
plt.title('Original')
plt.xticks([])
plt.yticks([])
plt.subplot(122)
plt.imshow(img_c, cmap = 'gray')
plt.title('C')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# * Compute and compare the mean square error between (image, image A), (image, image B), and (image, image C): $ MSE(f, g) = \frac{1}{MN} \sum_{i=0}^{M-1} \sum_{j=0}^{N-1} (f(i,j)-g(i,j)) ^ 2 $

# %%
def mse(img0, img1):
    return np.square(np.subtract(img0, img1)).mean()
print('MSE(image, image A) = %f' % mse(img, img_a))
print('MSE(image, image B) = %f' % mse(img, img_b))
print('MSE(image, image C) = %f' % mse(img, img_c))
# Out:
# MSE(image, image A) = 14289.062137
# MSE(image, image B) = 14853.607905
# MSE(image, image C) = 11303.413269

# %% [markdown]
# ### 2. Implement the adaptive medium filter and test with Figure 5.14 (a).

# %%
img = cv2.imread('img/figure5.14a.tif')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
blur = cv2.blur(img,(5,5))
plt.subplot(121)
plt.imshow(img)
plt.title('Original')
plt.xticks([])
plt.yticks([])
plt.subplot(122)
plt.imshow(blur)
plt.title('Adaptive Medium Filter')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# ### 3. Use the transfer function of a Butterworth high pass filter of order n to construct a homomorphic filter. Your filter must exhibit the characteristic shape shown below and must include the parameters shown in the figure.

# %%
img = cv2.imread('img/figure4.32.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('Figure 4.32')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
from scipy import signal
def homomorphic_filter(n):
    b, a = signal.butter(n, 10**-4, 'highpass', analog=True)
    w, h = signal.freqs(b, a)
    plt.plot(w, np.log10(abs(h)))
for i in range(1, 6):
    homomorphic_filter(i)
plt.title('Butterworth High Pass Filter')
plt.ylabel('H(u,v)')
plt.ylim(-5, 1)
plt.xlabel('D(u,v)')
plt.xscale('log')
plt.legend('12345', loc=4)
plt.hlines(0, 10**-6, 10**-3, linestyle=':')
plt.show()
